# %% [markdown]
# ## Lecture 3 demo
#
# There are 3 key themes to this lecture:
#
# 1. dates & times
#
# 2. strings
#
# 3. factors
#
# > Note: Whatever mentioned optional won't be tested in the assignment or exam.

# %% [markdown]
# First, let's load the packages we need:

# %%
library(tidyverse)
library(lubridate)
library(palmerpenguins)

# %% [markdown]
# *Note: if you have to install an R package that exists on CRAN, the command is: `install.packages("PACKAGE_NAME")`.*

# %% [markdown]
# And then let's limit the output of data frames in Jupyter to 6 lines:

# %%
options(repr.matrix.max.rows = 6)

# %% [markdown]
# > Show them cheat sheet. https://www.rstudio.com/resources/cheatsheets/
#
# > optional in lecture notes will not be tested in assignment or exam.

# %% [markdown]
# ## 1. Dates & times
#
# We learned about how to make date and time objects, but why are we doing this? What kinds of things can we do with these that are more difficult if we left these as characters or numeric vectors?
#
# - We can use date operations like `month`,`year` etc.
# - We can ask whether a date falls within a certain interval. Use the `interval` function to create an interval.
# - It impacts modeling and data visualization.(you will see in DSCI 531)
#
# Show them the datatypes image

# %% [markdown]
# # Clicker 1:
# For the following dataframe (`time_df`), give the code to list the rows where the week day is in Monday.
#
# | date_col    | other_col     |
# |-------------|---------------|
# | 15-1-2020   | Alice Wed |
# | 15-1-2019   | Bob Tue    |
# | 20-1-2019   | Charlie Sun     |
# | 30-1-2019   | Jab Wed     |
# | 13-1-2020   | Bobby Mon     |
#
# A) `time_df |> filter(wday(dmy(date_col), label = TRUE) == 'Mon')`
#
# B) `time_df |> filter(wday(dmy(date_col), label = TRUE) == 'Monday')`
#
# C) `time_df |> wday(dmy(date_col), label = TRUE) == 'Monday'`
#
# D) `time_df |> mutate(date_col = dmy(date_col)) |> filter(wday(date_col) == 1)`

# %% [markdown]
# Answer:
#
# A) `time_df |> filter(wday(dmy(date_col), label = TRUE) == 'Mon')`
#
# D) `time_df |> mutate(date_col = dmy(date_col)) |> filter(wday(date_col) == 1)`

# %%
time_df |> filter(wday(dmy(date_col),) == 'Monday')

# %% [markdown]
# # clicker 2:
#
# What will be the output of `print(time_df)` after running the following code?
#
# ```r
# time_df |> mutate(date_col = dmy(date_col)) |> filter(wday(date_col) == 1)
# ```
#
# A.
#
# | date_col    | other_col     |
# |-------------|---------------|
# | 15-1-2020   | Alice |
# | 15-1-2019   | Bob      |
# | 20-1-2019   | Charlie      |
# | 30-1-2019   | Jab      |
# | 13-1-2020   | Bobby     |
#
# B.
#
# | date_col    | other_col     |
# |-------------|---------------|
# | 13-1-2020   | Bobby     |

# %%
time_df <- time_df |> mutate(date_col = dmy(date_col)) |> filter(wday(date_col) == 1)
time_df_new <- time_df |> mutate(date_col = dmy(date_col)) |> filter(wday(date_col) == 1)

# %% [markdown]
# # answer:
#
# ANSWER: A
#
# Assign back to the original dataframe to keep the changes.

# %%
# time_df <- tibble(date_col = c("15-1-2020","15-1-2019","20-1-2019","30-1-2019","13-1-2020"),
#                    other_col = c("Alice", "Bob", "Charlie", "Jab", "Bobby"))
# time_df |> mutate(week_day = wday(dmy(date_col), abbr = FALSE, label = TRUE))

# %%
datev <- "01-01-2011"
typeof(datev)
# Won't run
# month(dmy(datev))
# month(datev)
# Out:
# [1] "character"
# [1] 1

# %%
datev <- dmy("31-Jan-2011")
datev <- mdy("Jan-31-2011")
class(datev)
month(datev)
# Out:
# [1] "Date"
# [1] 1

# %%
# setting up an interval 
my_interval <- interval(start = dmy("1-1-2019"), end = dmy("31-1-2019"))

# %% [markdown]
# - `%within%` is useful for pairing with `filter` to get rows in an interval

# %%
## see if 15-1-2019 is in this interval
dmy("15-1-2019") %within% my_interval
# Out:
# [1] TRUE

# %%
## How you apply this to a data frame
time_df <- tibble(date_col = c("15-1-2020","15-1-2019","20-1-2019","30-1-2019","13-1-2020"),
                   other_col = c("Alice", "Bob", "Charlie", "Jab", "Bobby"))
time_df |> mutate(date_col = dmy(date_col)) |> filter(date_col %within% my_interval)
# Out:
#   date_col   other_col
# 1 2019-01-15 Bob
# 2 2019-01-20 Charlie
# 3 2019-01-30 Jab

# %% [markdown]
# You will do this in the worksheet using `lubridate`'s `interval` function to create the interval, and then `filter` + `%within%` to subset rows from that interval.

# %% [markdown]
# ## 2. Strings
#
# My most common use for strings manipulation in data wrangling is filtering for rows where I have partial matches, and then replacing strings. The former can be done by pairing `filter` with`stringr`'s `str_detect` function, while the latter can be done by pairing `mutate` with `stringr`'s `str_replace` function.
#
# Other functions that can be quite useful are if you want to split a column in a dataframe into 2 separate columns or vice versa. The former can be done using `separate`, while the latter can be done using `unite`.
#
# Below I will demonstrate both on the `lakers` data frame below (which is the Los Angeles Lakers 2008-2009 basketball data set from the `lubridate` package):

# %%
str_length("gittu")
# Out:
# [1] 5

# %%
nchar("gittu")
# Out:
# [1] 5

# %%
lakers
# Out:
#       date     opponent game_type time  period etype     team
# 1     20081028 POR      home      12:00 1      jump ball OFF
# 2     20081028 POR      home      11:39 1      shot      LAL
# 3     20081028 POR      home      11:37 1      rebound   LAL
# ...   ...      ...      ...       ...   ...    ...       ...
# 34622 20090414 UTA      home      00:27 4      turnover  LAL
# 34623 20090414 UTA      home      00:21 4      shot      UTA
# 34624 20090414 UTA      home      00:20 4      rebound   LAL
#       player              result points type x   y
# 1                                0           NA  NA
# 2     Pau Gasol           missed 0      hook 23  13
# 3     Vladimir Radmanovic        0      off  NA  NA
# ...   ...                 ...    ...    ...  ... ...
# 34622 Andrew Bynum               0           NA  NA
# 34623 Kyle Korver         missed 0      3pt  41  25
# 34624 Luke Walton                0      def  NA  NA

# %% [markdown]
# Let's find all the rows where the player has the name Kyle:

# %%
lakers |>
  filter(str_detect(player, "Kyle"))
# Out:
#     date     opponent game_type time  period etype      team player      result
# 1   20081222 MEM      away      09:33 1      shot       MEM  Kyle Lowry  missed
# 2   20081222 MEM      away      04:59 1      rebound    MEM  Kyle Lowry
# 3   20081222 MEM      away      04:39 1      shot       MEM  Kyle Lowry  missed
# ... ...      ...      ...       ...   ...    ...        ...  ...         ...
# 127 20090414 UTA      home      00:42 4      free throw UTA  Kyle Korver made
# 128 20090414 UTA      home      00:42 4      free throw UTA  Kyle Korver made
# 129 20090414 UTA      home      00:21 4      shot       UTA  Kyle Korver missed
#     points type      x   y
# 1   0      3pt       13  28
# 2   0      def       NA  NA
# 3   0      jump bank 30  12
# ... ...    ...       ... ...
# 127 1                NA  NA
# 128 1                NA  NA
# 129 0      3pt       41  25

# %% [markdown]
# Wait !!! I am interested in knowing about Trevor as well.

# %%
# Filter that contain pattern "Kyle" or "Trevor" in column player. 
# We can do this by creating a pattern which would match them "Kyle|Trevor"
lakers |> 
    filter(str_detect(player,"Kyle|Trevor|James"))
# Out:
#      date     opponent game_type time  period etype      team player
# 1    20081028 POR      home      02:31 1      rebound    LAL  Trevor Ariza
# 2    20081028 POR      home      02:11 1      shot       LAL  Trevor Ariza
# 3    20081028 POR      home      01:31 1      shot       LAL  Trevor Ariza
# ...  ...      ...      ...       ...   ...    ...        ...  ...
# 1658 20090414 UTA      home      00:42 4      free throw UTA  Kyle Korver
# 1659 20090414 UTA      home      00:42 4      free throw UTA  Kyle Korver
# 1660 20090414 UTA      home      00:21 4      shot       UTA  Kyle Korver
#      result points type x   y
# 1           0      def  NA  NA
# 2    made   2      dunk 25   6
# 3    made   3      3pt  46  17
# ...  ...    ...    ...  ... ...
# 1658 made   1           NA  NA
# 1659 made   1           NA  NA
# 1660 missed 0      3pt  41  25

# %% [markdown]
# What if I am interested in knowing all players that starts with "Ky" ?
#
# # iclicker2:
# What code will you use to find all the players that starts with Ky?
#
# A) `lakers |> filter(str_detect(player, "^Ky"))`
#
# B) `lakers |> filter(str_detect(player, "Ky$"))`
#
# C) `lakers |> filter(str_detect(player, "Ky_"))`
#
# D) `lakers |> filter(str_detect(player, "Ky^"))`

# %% [markdown]
# Answer: A

# %%
## That starts with "Ky".
lakers |> 
    filter(str_detect(player,"^Ky"))
# Out:
#     date     opponent game_type time  period etype      team player      result
# 1   20081222 MEM      away      09:33 1      shot       MEM  Kyle Lowry  missed
# 2   20081222 MEM      away      04:59 1      rebound    MEM  Kyle Lowry
# 3   20081222 MEM      away      04:39 1      shot       MEM  Kyle Lowry  missed
# ... ...      ...      ...       ...   ...    ...        ...  ...         ...
# 136 20090414 UTA      home      00:42 4      free throw UTA  Kyle Korver made
# 137 20090414 UTA      home      00:42 4      free throw UTA  Kyle Korver made
# 138 20090414 UTA      home      00:21 4      shot       UTA  Kyle Korver missed
#     points type      x   y
# 1   0      3pt       13  28
# 2   0      def       NA  NA
# 3   0      jump bank 30  12
# ... ...    ...       ... ...
# 136 1                NA  NA
# 137 1                NA  NA
# 138 0      3pt       41  25

# %% [markdown]
# Sorry, but now I am interested in knowing all the player that ends with wry

# %%
## That ends with "wry"
lakers |> 
    filter(str_detect(player,"wry$"))
# Out:
#     date     opponent game_type time  period etype   team player     result
# 1   20081222 MEM      away      09:33 1      shot    MEM  Kyle Lowry missed
# 2   20081222 MEM      away      04:59 1      rebound MEM  Kyle Lowry
# 3   20081222 MEM      away      04:39 1      shot    MEM  Kyle Lowry missed
# ... ...      ...      ...       ...   ...    ...     ...  ...        ...
# 53  20090403 HOU      home      11:38 4      foul    HOU  Kyle Lowry
# 54  20090403 HOU      home      11:25 4      rebound HOU  Kyle Lowry
# 55  20090403 HOU      home      10:45 4      shot    HOU  Kyle Lowry missed
#     points type      x   y
# 1   0      3pt       13  28
# 2   0      def       NA  NA
# 3   0      jump bank 30  12
# ... ...    ...       ... ...
# 53  0      personal  NA  NA
# 54  0      def       NA  NA
# 55  0      layup     25   6

# %% [markdown]
# Do we have any rows with no player names ? Now, let's filter for all the rows that don't have a player name

# %%
## That contain empty value in column player $^
lakers |> 
    filter(str_detect(player," "))
# Out:
#       date     opponent game_type time  period etype    team
# 1     20081028 POR      home      11:39 1      shot     LAL
# 2     20081028 POR      home      11:37 1      rebound  LAL
# 3     20081028 POR      home      11:25 1      shot     LAL
# ...   ...      ...      ...       ...   ...    ...      ...
# 29224 20090414 UTA      home      00:27 4      turnover LAL
# 29225 20090414 UTA      home      00:21 4      shot     UTA
# 29226 20090414 UTA      home      00:20 4      rebound  LAL
#       player              result points type  x   y
# 1     Pau Gasol           missed 0      hook  23  13
# 2     Vladimir Radmanovic        0      off   NA  NA
# 3     Derek Fisher        missed 0      layup 25   6
# ...   ...                 ...    ...    ...   ... ...
# 29224 Andrew Bynum               0            NA  NA
# 29225 Kyle Korver         missed 0      3pt   41  25
# 29226 Luke Walton                0      def   NA  NA

# %% [markdown]
# Next, let's change some of the text so it is more readable - so "3pt" to "3 point":

# %%
lakers |>
  mutate(type = str_replace(type, "3pt", "3 point"))
# Out:
#       date     opponent game_type time  period etype     team
# 1     20081028 POR      home      12:00 1      jump ball OFF
# 2     20081028 POR      home      11:39 1      shot      LAL
# 3     20081028 POR      home      11:37 1      rebound   LAL
# ...   ...      ...      ...       ...   ...    ...       ...
# 34622 20090414 UTA      home      00:27 4      turnover  LAL
# 34623 20090414 UTA      home      00:21 4      shot      UTA
# 34624 20090414 UTA      home      00:20 4      rebound   LAL
#       player              result points type    x   y
# 1                                0              NA  NA
# 2     Pau Gasol           missed 0      hook    23  13
# 3     Vladimir Radmanovic        0      off     NA  NA
# ...   ...                 ...    ...    ...     ... ...
# 34622 Andrew Bynum               0              NA  NA
# 34623 Kyle Korver         missed 0      3 point 41  25
# 34624 Luke Walton                0      def     NA  NA

# %% [markdown]
# Now let's try to separate out column `player` into 2 columns `player_f_name` and `player_l_name`.

# %%
new_lakers <- lakers |> separate(player, into = c("player_f_name","player_l_name"), sep = " ")
head(new_lakers)
# Out:
# Warning message:
# "Expected 2 pieces. Additional pieces discarded in 59 rows [2417, 2419, 5601,
# 5615, 5617, 5655, 5666, 5668, 5681, 5684, 5704, 5714, 5718, 5777, 5788, 7745,
# 7748, 7770, 7785, 7816, ...]."
# Warning message:
# "Expected 2 pieces. Missing pieces filled with `NA` in 5398 rows [1, 35, 40, 44,
# 50, 51, 52, 69, 70, 81, 82, 83, 84, 96, 97, 105, 110, 114, 123, 127, ...]."
#   date     opponent game_type time  period etype     team player_f_name
# 1 20081028 POR      home      12:00 1      jump ball OFF
# 2 20081028 POR      home      11:39 1      shot      LAL  Pau
# 3 20081028 POR      home      11:37 1      rebound   LAL  Vladimir
# 4 20081028 POR      home      11:25 1      shot      LAL  Derek
# 5 20081028 POR      home      11:23 1      rebound   LAL  Pau
# 6 20081028 POR      home      11:22 1      shot      LAL  Pau
#   player_l_name result points type  x  y
# 1 NA                   0            NA NA
# 2 Gasol         missed 0      hook  23 13
# 3 Radmanovic           0      off   NA NA
# 4 Fisher        missed 0      layup 25  6
# 5 Gasol                0      off   NA NA
# 6 Gasol         made   2      hook  25 10

# %% [markdown]
# Now let's those columns back to a single column `player`.

# %%
new_lakers |> unite(col = "player", c(player_f_name,player_l_name), sep= " ")
# Out:
#       date     opponent game_type time  period etype     team
# 1     20081028 POR      home      12:00 1      jump ball OFF
# 2     20081028 POR      home      11:39 1      shot      LAL
# 3     20081028 POR      home      11:37 1      rebound   LAL
# ...   ...      ...      ...       ...   ...    ...       ...
# 34622 20090414 UTA      home      00:27 4      turnover  LAL
# 34623 20090414 UTA      home      00:21 4      shot      UTA
# 34624 20090414 UTA      home      00:20 4      rebound   LAL
#       player              result points type x   y
# 1      NA                        0           NA  NA
# 2     Pau Gasol           missed 0      hook 23  13
# 3     Vladimir Radmanovic        0      off  NA  NA
# ...   ...                 ...    ...    ...  ... ...
# 34622 Andrew Bynum               0           NA  NA
# 34623 Kyle Korver         missed 0      3pt  41  25
# 34624 Luke Walton                0      def  NA  NA

# %% [markdown]
# ## 3. Factors

# %% [markdown]
# Show them datatype image....
#
# Factors are a kind of vector in R. And remember - data frame columns are usually made up of vectors - so you most commonly encounter them as columns in a data frame. They are very useful for modeling and data visualization.

# %% [markdown]
# Let's see what happens when we convert the `etype` column in the `lakers` data frame to a factor, as well as how we can do that:

# %% [markdown]
# First, let's look at what the column originally is:

# %%
class(lakers$etype)
str(lakers$etype)
# str(lakers)
as.factor(lakers$etype)
# Out:
# [1] "character"
#  chr [1:34624] "jump ball" "shot" "rebound" "shot" "rebound" "shot" "foul" ...
#     [1] jump ball  shot       rebound    shot       rebound    shot
#     [7] foul       free throw foul       shot       shot       shot
#    [13] rebound    shot       shot       shot       rebound    shot
#    [19] shot       rebound    shot       rebound    foul       shot
#    [25] rebound    foul       shot       rebound    shot       rebound
#    [31] turnover   shot       rebound    shot       timeout    shot
#    [37] rebound    foul       turnover   sub        shot       turnover
#    [43] shot       rebound    shot       rebound    shot       rebound
#    [49] shot       rebound    sub        sub        turnover   shot
#    [55] rebound    shot       rebound    shot       shot       rebound
#    [61] shot       rebound    foul       shot       shot       shot
#    [67] rebound    shot       rebound    sub        shot       rebound
#    [73] shot       rebound    turnover   shot       rebound    shot
#    [79] rebound    turnover   timeout    sub        sub        sub
#    [85] shot       shot       rebound    foul       free throw rebound
#    [91] shot       shot       shot       shot       turnover   sub
#    [97] sub        shot       rebound    shot       rebound    shot
#   [103] rebound    foul       sub        free throw free throw shot
#   [109] shot       rebound    shot       rebound    shot       rebound
#   [115] shot       rebound    shot       violation  foul       free throw
#   [121] rebound    shot       rebound    shot       turnover   shot
#   [127] timeout    sub        sub        shot       shot       rebound
#   [133] turnover   shot       rebound    shot       rebound    shot
#   [139] rebound    shot       turnover   sub        sub        shot
#   [145] rebound    shot       rebound    shot       rebound    shot
#   [151] turnover   shot       shot       foul       free throw sub
#   [157] free throw shot       rebound    shot       rebound    shot
#   [163] foul       timeout    sub        sub        sub        foul
#   [169] free throw rebound    free throw rebound    shot       rebound
#   [175] shot       foul       shot       rebound    turnover   shot
#   [181] shot       rebound    turnover   shot       violation  shot
#   [187] rebound    shot       shot       rebound    turnover   shot
#   [193] shot       timeout    timeout    sub        turnover   turnover
#   [199] foul       free throw free throw shot       rebound    shot
#   [205] rebound    shot       shot       rebound    shot       turnover
#   [211] shot       rebound    shot       shot       rebound    shot
#   [217] shot       rebound    shot       rebound    shot       rebound
#   [223] shot       rebound    shot       shot       rebound    shot
#   [229] rebound    foul       shot       shot       rebound    shot
#   [235] foul       free throw rebound    shot       rebound    shot
#   [241] rebound    turnover   shot       rebound    shot       rebound
#   [247] foul       free throw sub        free throw shot       rebound
#   [253] foul       free throw timeout    free throw shot       rebound
#   [259] turnover   shot       shot       shot       rebound    shot
#   [265] shot       foul       sub        sub        free throw free throw
#   [271] violation  shot       rebound    shot       foul       shot
#   [277] rebound    turnover   turnover   timeout    sub        sub
#   [283] sub        shot       shot       rebound    shot       shot
#   [289] rebound    shot       foul       free throw sub        free throw
#   [295] shot       rebound    foul       free throw rebound    free throw
#   [301] shot       rebound    shot       rebound    foul       shot
#   [307] rebound    shot       shot       rebound    jump ball  shot
#   [313] rebound    foul       turnover   shot       shot       rebound
#   [319] rebound    foul       foul       free throw foul       shot
#   [325] shot       shot       rebound    foul       sub        free throw
#   [331] sub        free throw foul       turnover   foul       shot
#   [337] timeout    shot       turnover   shot       rebound    turnover
#   [343] shot       shot       shot       rebound    shot       foul
#   [349] free throw shot       shot       rebound    shot       shot
#   [355] shot       rebound    rebound    shot       rebound    turnover
#   [361] shot       shot       rebound    shot       rebound    shot
#   [367] foul       timeout    sub        sub        free throw rebound
#   [373] free throw rebound    shot       shot       rebound    turnover
#   [379] shot       shot       foul       sub        sub        sub
#   [385] free throw rebound    free throw shot       rebound    shot
#   [391] rebound    foul       timeout    sub        sub        shot
#   [397] rebound    shot       rebound    turnover   turnover   shot
#   [403] shot       rebound    shot       rebound    shot       shot
#   [409] rebound    foul       free throw free throw shot       shot
#   [415] rebound    shot       jump ball  shot       shot       rebound
#   [421] shot       shot       rebound    shot       rebound    shot
#   [427] foul       shot       shot       rebound    shot       violation
#   [433] shot       shot       rebound    turnover   foul       free throw
#   [439] rebound    free throw rebound    shot       shot       shot
#   [445] rebound    foul       free throw sub        free throw shot
#   [451] rebound    shot       shot       foul       free throw shot
#   [457] rebound    shot       rebound    turnover   shot       shot
#   [463] shot       shot       rebound    shot       rebound    turnover
#   [469] shot       foul       timeout    sub        free throw shot
#   [475] foul       turnover   shot       foul       free throw shot
#   [481] rebound    shot       shot       rebound    shot       rebound
#   [487] shot       rebound    foul       free throw sub        free throw
#   [493] turnover   timeout    sub        sub        shot       rebound
#   [499] shot       shot       foul       turnover   shot       turnover
#   [505] shot       foul       sub        free throw sub        turnover
#   [511] foul       turnover   shot       rebound    shot       rebound
#   [517] shot       rebound    shot       foul       free throw free throw
#   [523] shot       rebound    shot       foul       shot       shot
#   [529] rebound    shot       rebound    shot       rebound    foul
#   [535] free throw rebound    free throw rebound    turnover   foul
#   [541] turnover   shot       violation  foul       free throw rebound
#   [547] shot       rebound    shot       rebound    shot       rebound
#   [553] foul       timeout    sub        shot       shot       rebound
#   [559] shot       foul       turnover   shot       shot       rebound
#   [565] shot       timeout    sub        sub        sub        sub
#   [571] sub        shot       rebound    foul       free throw rebound
#   [577] free throw rebound    shot       rebound    shot       foul
#   [583] shot       rebound    timeout    shot       rebound    shot
#   [589] shot       rebound    shot       rebound    shot       rebound
#   [595] sub        sub        shot       shot       shot       rebound
#   [601] shot       timeout    sub        sub        turnover   foul
#   [607] free throw rebound    free throw shot       rebound    turnover
#   [613] foul       shot       rebound    foul       turnover   shot
#   [619] turnover   shot       foul       free throw sub        sub
#   [625] free throw rebound    foul       free throw free throw shot
#   [631] shot       foul       free throw sub        sub        free throw
#   [637] shot       rebound    shot       shot       shot       rebound
#   [643] shot       rebound    turnover   foul       free throw rebound
#   [649] free throw turnover   shot       shot       rebound    shot
#   [655] rebound    foul       free throw free throw shot       rebound
#   [661] shot       rebound    foul       foul       turnover   foul
#   [667] free throw rebound    free throw rebound    turnover   shot
#   [673] rebound    shot       rebound    shot       rebound    foul
#   [679] shot       rebound    turnover   shot       shot       rebound
#   [685] rebound    shot       foul       sub        free throw shot
#   [691] rebound    shot       rebound    shot       foul       free throw
#   [697] rebound    free throw rebound    shot       rebound    shot
#   [703] shot       shot       rebound    shot       rebound    timeout
#   [709] sub        shot       turnover   shot       turnover   shot
#   [715] rebound    foul       sub        sub        foul       turnover
#   [721] shot       shot       rebound    shot       shot       rebound
#   [727] shot       rebound    shot       rebound    shot       rebound
#   [733] foul       timeout    sub        sub        sub        free throw
#   [739] free throw shot       rebound    shot       rebound    shot
#   [745] foul       free throw rebound    free throw shot       rebound
#   [751] shot       rebound    shot       foul       sub        free throw
#   [757] free throw shot       turnover   shot       rebound    turnover
#   [763] shot       rebound    foul       shot       rebound    turnover
#   [769] shot       shot       shot       shot       shot       rebound
#   [775] foul       free throw free throw turnover   foul       free throw
#   [781] free throw foul       foul       turnover   sub        shot
#   [787] rebound    timeout    sub        foul       free throw free throw
#   [793] shot       shot       shot       rebound    rebound    turnover
#   [799] foul       free throw rebound    sub        free throw turnover
#   [805] shot       shot       shot       rebound    shot       shot
#   [811] turnover   sub        shot       rebound    foul       timeout
#   [817] sub        sub        free throw free throw foul       shot
#   [823] shot       turnover   violation  shot       rebound    foul
#   [829] sub        free throw free throw foul       free throw free throw
#   [835] shot       shot       shot       rebound    foul       free throw
#   [841] rebound    free throw shot       shot       rebound    shot
#   [847] rebound    shot       shot       shot       shot       rebound
#   [853] shot       rebound    shot       rebound    timeout    sub
#   [859] shot       rebound    shot       rebound    shot       rebound
#   [865] shot       shot       rebound    turnover   shot       shot
#   [871] rebound    jump ball  shot       rebound    shot       rebound
#   [877] shot       rebound    turnover   turnover   turnover   foul
#   [883] turnover   shot       rebound    shot       foul       turnover
#   [889] shot       rebound    shot       rebound    foul       free throw
#   [895] free throw rebound    shot       rebound    shot       shot
#   [901] shot       rebound    rebound    shot       shot       rebound
#   [907] foul       turnover   shot       shot       shot       shot
#   [913] rebound    shot       shot       rebound    shot       foul
#   [919] free throw free throw turnover   shot       shot       rebound
#   [925] shot       turnover   shot       foul       timeout    sub
#   [931] free throw shot       rebound    shot       rebound    shot
#   [937] shot       rebound    foul       free throw free throw shot
#   [943] rebound    turnover   sub        sub        shot       shot
#   [949] rebound    rebound    shot       rebound    shot       shot
#   [955] rebound    rebound    shot       rebound    shot       rebound
#   [961] foul       free throw free throw foul       timeout    sub
#   [967] sub        sub        free throw free throw rebound    foul
#   [973] turnover   shot       shot       turnover   shot       rebound
#   [979] foul       sub        turnover   shot       foul       sub
#   [985] free throw rebound    free throw rebound    foul       free throw
#   [991] sub        free throw rebound    violation  shot       shot
#   [997] rebound    shot       rebound    foul       free throw free throw
#  [1003] shot       shot       rebound    rebound    turnover   shot
#  [1009] rebound    foul       shot       shot       rebound    rebound
#  [1015] shot       rebound    turnover   shot       shot       rebound
#  [1021] sub        shot       shot       rebound    turnover   timeout
#  [1027] shot       foul       free throw free throw rebound    shot
#  [1033] shot       rebound    sub        shot       shot       foul
#  [1039] shot       shot       rebound    shot       rebound    turnover
#  [1045] shot       rebound    shot       violation  shot       turnover
#  [1051] foul       sub        free throw rebound    sub        sub
#  [1057] sub        free throw turnover   shot       rebound    shot
#  [1063] foul       sub        free throw rebound    shot       shot
#  [1069] rebound    foul       turnover   timeout    sub        sub
#  [1075] shot       rebound    foul       free throw free throw foul
#  [1081] sub        shot       turnover   shot       rebound    shot
#  [1087] rebound    shot       rebound    foul       sub        foul
#  [1093] free throw free throw shot       shot       rebound    shot
#  [1099] rebound    shot       rebound    shot       shot       rebound
#  [1105] foul       timeout    free throw rebound    free throw rebound
#  [1111] shot       shot       rebound    shot       rebound    shot
#  [1117] foul       free throw free throw turnover   shot       foul
#  [1123] free throw sub        free throw shot       foul       free throw
#  [1129] shot       rebound    foul       sub        free throw sub
#  [1135] free throw shot       rebound    shot       shot       rebound
#  [1141] foul       free throw free throw shot       foul       turnover
#  [1147] shot       rebound    sub        shot       shot       foul
#  [1153] free throw free throw free throw rebound    shot       shot
#  [1159] shot       foul       shot       rebound    shot       shot
#  [1165] shot       rebound    shot       shot       rebound    shot
#  [1171] timeout    sub        shot       turnover   shot       rebound
#  [1177] shot       rebound    shot       rebound    turnover   shot
#  [1183] shot       rebound    shot       rebound    timeout    shot
#  [1189] rebound    shot       rebound    foul       free throw rebound
#  [1195] free throw shot       shot       foul       sub        free throw
#  [1201] shot       rebound    shot       shot       rebound    shot
#  [1207] rebound    turnover   sub        shot       shot       shot
#  [1213] rebound    foul       sub        turnover   foul       free throw
#  [1219] rebound    sub        free throw shot       shot       rebound
#  [1225] timeout    foul       free throw rebound    sub        free throw
#  [1231] shot       shot       rebound    shot       turnover   foul
#  [1237] free throw sub        free throw turnover   shot       rebound
#  [1243] turnover   turnover   shot       rebound    shot       rebound
#  [1249] turnover   shot       rebound    shot       rebound    foul
#  [1255] free throw free throw rebound    sub        sub        shot
#  [1261] foul       free throw free throw shot       rebound    foul
#  [1267] free throw sub        free throw shot       rebound    foul
#  [1273] free throw rebound    free throw foul       free throw free throw
#  [1279] shot       rebound    shot       shot       rebound    turnover
#  [1285] timeout    sub        shot       rebound    foul       free throw
#  [1291] sub        free throw turnover   shot       rebound    foul
#  [1297] free throw free throw turnover   shot       timeout    sub
#  [1303] sub        sub        shot       shot       rebound    shot
#  [1309] turnover   shot       rebound    shot       rebound    foul
#  [1315] sub        free throw free throw rebound    shot       rebound
#  [1321] foul       sub        free throw rebound    sub        free throw
#  [1327] shot       shot       rebound    shot       shot       rebound
#  [1333] shot       rebound    shot       rebound    shot       foul
#  [1339] timeout    free throw rebound    free throw rebound    shot
#  [1345] shot       rebound    shot       timeout    shot       rebound
#  [1351] shot       rebound    shot       foul       free throw sub
#  [1357] free throw shot       foul       free throw free throw timeout
#  [1363] shot       rebound    jump ball  shot       rebound    shot
#  [1369] shot       shot       rebound    shot       rebound    shot
#  [1375] rebound    shot       rebound    foul       shot       rebound
#  [1381] foul       shot       rebound    shot       shot       shot
#  [1387] rebound    shot       foul       sub        free throw rebound
#  [1393] shot       rebound    shot       rebound    shot       shot
#  [1399] shot       shot       rebound    shot       shot       rebound
#  [1405] shot       shot       shot       foul       free throw rebound
#  [1411] free throw shot       rebound    shot       shot       shot
#  [1417] shot       rebound    shot       rebound    shot       timeout
#  [1423] turnover   shot       rebound    foul       free throw sub
#  [1429] free throw shot       shot       rebound    shot       shot
#  [1435] shot       rebound    shot       foul       free throw rebound
#  [1441] free throw shot       rebound    foul       free throw sub
#  [1447] free throw turnover   shot       rebound    shot       shot
#  [1453] rebound    shot       rebound    shot       rebound    turnover
#  [1459] turnover   shot       rebound    timeout    sub        sub
#  [1465] sub        shot       rebound    shot       rebound    turnover
#  [1471] foul       free throw rebound    free throw rebound    shot
#  [1477] rebound    shot       rebound    shot       rebound    turnover
#  [1483] shot       shot       rebound    shot       rebound    shot
#  [1489] rebound    shot       shot       rebound    shot       rebound
#  [1495] sub        shot       turnover   shot       shot       rebound
#  [1501] shot       rebound    shot       timeout    sub        shot
#  [1507] rebound    foul       free throw free throw rebound    shot
#  [1513] rebound    turnover   shot       foul       foul       free throw
#  [1519] free throw shot       rebound    timeout    sub        sub
#  [1525] shot       rebound    shot       rebound    shot       rebound
#  [1531] shot       rebound    shot       rebound    shot       rebound
#  [1537] turnover   foul       free throw rebound    sub        sub
#  [1543] sub        free throw shot       rebound    foul       foul
#  [1549] sub        foul       shot       turnover   foul       free throw
#  [1555] sub        free throw rebound    turnover   turnover   shot
#  [1561] rebound    shot       sub        rebound    sub        jump ball
#  [1567] rebound    shot       shot       shot       rebound    shot
#  [1573] foul       sub        sub        free throw free throw turnover
#  [1579] foul       free throw free throw foul       free throw free throw
#  [1585] turnover   shot       shot       rebound    shot       turnover
#  [1591] shot       foul       free throw shot       rebound    shot
#  [1597] shot       shot       shot       rebound    shot       rebound
#  [1603] foul       shot       shot       rebound    turnover   shot
#  [1609] rebound    foul       foul       shot       rebound    turnover
#  [1615] foul       turnover   shot       turnover   shot       rebound
#  [1621] shot       shot       rebound    shot       foul       free throw
#  [1627] timeout    sub        shot       violation  shot       rebound
#  [1633] shot       rebound    shot       foul       free throw free throw
#  [1639] shot       rebound    shot       shot       turnover   shot
#  [1645] rebound    foul       free throw rebound    free throw rebound
#  [1651] shot       rebound    shot       shot       rebound    shot
#  [1657] shot       shot       rebound    shot       rebound    shot
#  [1663] rebound    foul       timeout    sub        shot       rebound
#  [1669] shot       rebound    foul       sub        shot       rebound
#  [1675] shot       rebound    foul       free throw rebound    free throw
#  [1681] shot       rebound    shot       rebound    shot       rebound
#  [1687] shot       shot       rebound    shot       rebound    shot
#  [1693] rebound    shot       shot       foul       turnover   timeout
#  [1699] sub        sub        sub        sub        sub        shot
#  [1705] rebound    shot       shot       rebound    shot       rebound
#  [1711] shot       shot       shot       rebound    foul       sub
#  [1717] free throw sub        sub        free throw rebound    shot
#  [1723] rebound    shot       rebound    shot       rebound    shot
#  [1729] shot       rebound    foul       shot       rebound    shot
#  [1735] rebound    foul       turnover   shot       foul       free throw
#  [1741] turnover   shot       shot       shot       shot       rebound
#  [1747] foul       foul       free throw shot       rebound    foul
#  [1753] timeout    sub        sub        free throw free throw shot
#  [1759] turnover   shot       foul       sub        free throw rebound
#  [1765] sub        free throw turnover   shot       rebound    foul
#  [1771] free throw rebound    sub        free throw shot       rebound
#  [1777] shot       rebound    turnover   foul       free throw free throw
#  [1783] shot       rebound    foul       free throw free throw foul
#  [1789] turnover   shot       rebound    shot       timeout    sub
#  [1795] sub        sub        sub        sub        shot       rebound
#  [1801] turnover   foul       free throw free throw rebound    shot
#  [1807] rebound    shot       rebound    shot       foul       shot
#  [1813] rebound    foul       sub        turnover   shot       shot
#  [1819] rebound    shot       rebound    foul       free throw free throw
#  [1825] shot       rebound    shot       shot       rebound    foul
#  [1831] timeout    free throw rebound    free throw shot       rebound
#  [1837] foul       free throw sub        sub        free throw turnover
#  [1843] shot       rebound    shot       rebound    sub        sub
#  [1849] sub        shot       shot       shot       rebound    shot
#  [1855] foul       free throw rebound    foul       sub        free throw
#  [1861] rebound    free throw turnover   foul       free throw free throw
#  [1867] shot       jump ball  shot       rebound    shot       rebound
#  [1873] shot       rebound    shot       rebound    shot       rebound
#  [1879] shot       rebound    shot       shot       shot       turnover
#  [1885] shot       turnover   shot       shot       rebound    rebound
#  [1891] turnover   shot       rebound    shot       rebound    shot
#  [1897] shot       rebound    shot       rebound    foul       free throw
#  [1903] rebound    free throw turnover   turnover   shot       foul
#  [1909] shot       rebound    shot       turnover   shot       turnover
#  [1915] shot       shot       rebound    turnover   shot       timeout
#  [1921] shot       shot       rebound    rebound    shot       rebound
#  [1927] turnover   shot       rebound    shot       rebound    shot
#  [1933] rebound    shot       shot       turnover   foul       timeout
#  [1939] sub        sub        sub        free throw free throw turnover
#  [1945] shot       shot       rebound    rebound    shot       foul
#  [1951] free throw sub        free throw shot       rebound    foul
#  [1957] free throw rebound    sub        free throw shot       rebound
#  [1963] foul       free throw sub        free throw shot       rebound
#  [1969] shot       turnover   shot       rebound    shot       foul
#  [1975] free throw shot       shot       shot       rebound    shot
#  [1981] rebound    shot       foul       shot       turnover   foul
#  [1987] shot       turnover   shot       shot       timeout    shot
#  [1993] shot       shot       shot       foul       free throw sub
#  [1999] free throw rebound    foul       shot       turnover   turnover
#  [2005] shot       turnover   shot       rebound    foul       free throw
#  [2011] free throw shot       shot       rebound    shot       rebound
#  [2017] shot       rebound    shot       rebound    foul       free throw
#  [2023] rebound    free throw turnover   shot       shot       shot
#  [2029] timeout    sub        sub        sub        sub        shot
#  [2035] rebound    shot       rebound    shot       timeout    sub
#  [2041] shot       rebound    shot       rebound    foul       sub
#  [2047] sub        free throw free throw turnover   shot       rebound
#  [2053] shot       rebound    turnover   shot       shot       rebound
#  [2059] shot       rebound    shot       rebound    shot       shot
#  [2065] rebound    turnover   shot       shot       rebound    rebound
#  [2071] foul       timeout    sub        free throw free throw foul
#  [2077] sub        shot       rebound    shot       shot       rebound
#  [2083] turnover   foul       free throw free throw foul       free throw
#  [2089] rebound    sub        free throw turnover   shot       rebound
#  [2095] shot       rebound    shot       rebound    foul       foul
#  [2101] foul       free throw rebound    free throw shot       rebound
#  [2107] turnover   shot       shot       rebound    shot       rebound
#  [2113] shot       rebound    shot       rebound    turnover   shot
#  [2119] foul       shot       rebound    shot       rebound    shot
#  [2125] shot       rebound    turnover   shot       shot       shot
#  [2131] rebound    shot       rebound    shot       timeout    shot
#  [2137] shot       rebound    shot       shot       rebound    foul
#  [2143] foul       free throw rebound    free throw rebound    shot
#  [2149] shot       rebound    shot       shot       rebound    shot
#  [2155] shot       rebound    shot       rebound    shot       rebound
#  [2161] foul       sub        sub        free throw timeout    sub
#  [2167] sub        free throw turnover   shot       rebound    turnover
#  [2173] shot       shot       shot       shot       rebound    violation
#  [2179] sub        sub        shot       rebound    shot       rebound
#  [2185] shot       rebound    shot       shot       rebound    shot
#  [2191] shot       foul       free throw turnover   shot       turnover
#  [2197] shot       shot       rebound    shot       shot       shot
#  [2203] rebound    shot       shot       rebound    shot       timeout
#  [2209] sub        sub        sub        foul       shot       rebound
#  [2215] shot       turnover   shot       shot       shot       rebound
#  [2221] shot       rebound    shot       foul       free throw sub
#  [2227] foul       shot       shot       foul       turnover   timeout
#  [2233] sub        shot       rebound    turnover   shot       shot
#  [2239] shot       sub        foul       free throw rebound    free throw
#  [2245] rebound    shot       rebound    turnover   foul       free throw
#  [2251] rebound    free throw shot       rebound    turnover   shot
#  [2257] foul       free throw foul       free throw free throw turnover
#  [2263] shot       shot       rebound    shot       shot       rebound
#  [2269] foul       turnover   timeout    sub        sub        sub
#  [2275] sub        sub        sub        sub        shot       rebound
#  [2281] shot       rebound    shot       rebound    turnover   shot
#  [2287] foul       free throw free throw shot       shot       rebound
#  [2293] jump ball  shot       shot       shot       rebound    rebound
#  [2299] foul       free throw free throw shot       shot       shot
#  [2305] shot       rebound    rebound    shot       rebound    shot
#  [2311] rebound    shot       shot       rebound    foul       turnover
#  [2317] shot       shot       rebound    turnover   turnover   turnover
#  [2323] shot       shot       turnover   foul       free throw free throw
#  [2329] shot       rebound    shot       shot       rebound    shot
#  [2335] shot       rebound    foul       free throw shot       rebound
#  [2341] turnover   shot       rebound    shot       shot       rebound
#  [2347] foul       shot       rebound    shot       rebound    foul
#  [2353] free throw timeout    free throw shot       rebound    foul
#  [2359] free throw sub        sub        free throw shot       turnover
#  [2365] shot       foul       free throw shot       rebound    shot
#  [2371] shot       rebound    shot       rebound    foul       free throw
#  [2377] sub        free throw timeout    sub        sub        turnover
#  [2383] shot       shot       rebound    sub        sub        shot
#  [2389] rebound    shot       shot       shot       shot       rebound
#  [2395] shot       rebound    shot       rebound    shot       turnover
#  [2401] shot       turnover   shot       shot       rebound    shot
#  [2407] foul       free throw rebound    sub        free throw turnover
#  [2413] shot       shot       rebound    turnover   turnover   shot
#  [2419] rebound    shot       rebound    shot       foul       free throw
#  [2425] sub        shot       rebound    shot       shot       violation
#  [2431] shot       turnover   foul       timeout    free throw rebound
#  [2437] free throw shot       rebound    shot       shot       rebound
#  [2443] shot       shot       rebound    shot       rebound    shot
#  [2449] rebound    foul       turnover   sub        sub        shot
#  [2455] rebound    shot       shot       rebound    shot       shot
#  [2461] shot       shot       rebound    turnover   turnover   shot
#  [2467] rebound    turnover   foul       timeout    sub        sub
#  [2473] sub        free throw free throw shot       shot       shot
#  [2479] shot       rebound    shot       shot       rebound    shot
#  [2485] violation  sub        shot       foul       turnover   sub
#  [2491] shot       rebound    shot       rebound    shot       foul
#  [2497] timeout    sub        sub        free throw free throw rebound
#  [2503] shot       shot       rebound    shot       foul       free throw
#  [2509] rebound    jump ball  shot       rebound    shot       shot
#  [2515] rebound    foul       turnover   shot       foul       timeout
#  [2521] free throw foul       sub        sub        free throw free throw
#  [2527] foul       free throw rebound    sub        sub        free throw
#  [2533] shot       shot       rebound    shot       foul       free throw
#  [2539] free throw rebound    shot       rebound    turnover   shot
#  [2545] rebound    turnover   shot       rebound    turnover   shot
#  [2551] rebound    shot       shot       rebound    turnover   shot
#  [2557] foul       shot       rebound    foul       shot       rebound
#  [2563] shot       shot       rebound    shot       rebound    sub
#  [2569] shot       rebound    shot       shot       rebound    shot
#  [2575] shot       rebound    shot       rebound    turnover   foul
#  [2581] free throw sub        free throw shot       shot       rebound
#  [2587] timeout    sub        sub        shot       rebound    shot
#  [2593] rebound    shot       rebound    shot       shot       rebound
#  [2599] shot       rebound    shot       shot       rebound    foul
#  [2605] free throw rebound    sub        free throw rebound    shot
#  [2611] rebound    shot       rebound    shot       shot       shot
#  [2617] rebound    timeout    sub        sub        sub        sub
#  [2623] sub        sub        shot       rebound    foul       free throw
#  [2629] rebound    free throw turnover   turnover   timeout    shot
#  [2635] shot       shot       rebound    shot       shot       rebound
#  [2641] shot       rebound    shot       violation  turnover   shot
#  [2647] shot       shot       shot       rebound    foul       turnover
#  [2653] turnover   shot       rebound    shot       shot       shot
#  [2659] rebound    rebound    shot       rebound    shot       shot
#  [2665] rebound    shot       foul       sub        free throw rebound
#  [2671] shot       timeout    sub        foul       shot       rebound
#  [2677] shot       rebound    shot       rebound    foul       free throw
#  [2683] rebound    sub        sub        free throw rebound    shot
#  [2689] shot       rebound    shot       rebound    shot       shot
#  [2695] turnover   shot       shot       shot       rebound    sub
#  [2701] sub        sub        shot       rebound    shot       shot
#  [2707] rebound    shot       foul       timeout    free throw turnover
#  [2713] shot       rebound    shot       rebound    shot       rebound
#  [2719] shot       foul       free throw shot       foul       free throw
#  [2725] shot       rebound    foul       shot       shot       rebound
#  [2731] foul       free throw timeout    sub        free throw shot
#  [2737] rebound    foul       free throw sub        free throw foul
#  [2743] free throw free throw shot       rebound    shot       rebound
#  [2749] foul       free throw rebound    sub        free throw jump ball
#  [2755] turnover   shot       rebound    shot       rebound    shot
#  [2761] rebound    shot       rebound    timeout    sub        shot
#  [2767] rebound    turnover   sub        shot       rebound    shot
#  [2773] foul       sub        sub        free throw shot       foul
#  [2779] free throw free throw timeout    turnover   turnover   shot
#  [2785] rebound    foul       free throw free throw turnover   jump ball
#  [2791] shot       shot       rebound    turnover   shot       foul
#  [2797] shot       shot       rebound    shot       shot       rebound
#  [2803] shot       shot       rebound    shot       turnover   shot
#  [2809] shot       foul       free throw shot       rebound    shot
#  [2815] shot       rebound    shot       rebound    shot       rebound
#  [2821] shot       rebound    shot       rebound    shot       rebound
#  [2827] shot       rebound    shot       rebound    shot       rebound
#  [2833] shot       rebound    shot       rebound    shot       foul
#  [2839] timeout    turnover   shot       shot       rebound    shot
#  [2845] rebound    foul       free throw free throw rebound    foul
#  [2851] turnover   sub        shot       timeout    foul       turnover
#  [2857] turnover   shot       shot       rebound    shot       foul
#  [2863] sub        sub        sub        sub        shot       rebound
#  [2869] foul       shot       rebound    shot       shot       shot
#  [2875] rebound    turnover   shot       foul       free throw rebound
#  [2881] sub        sub        free throw rebound    shot       rebound
#  [2887] turnover   shot       foul       shot       rebound    shot
#  [2893] shot       rebound    shot       rebound    foul       turnover
#  [2899] shot       shot       shot       rebound    shot       shot
#  [2905] shot       rebound    shot       shot       shot       rebound
#  [2911] turnover   foul       timeout    sub        sub        sub
#  [2917] shot       shot       shot       rebound    turnover   shot
#  [2923] shot       foul       sub        sub        free throw shot
#  [2929] foul       free throw shot       shot       shot       shot
#  [2935] foul       shot       shot       rebound    turnover   timeout
#  [2941] timeout    turnover   shot       rebound    shot       foul
#  [2947] turnover   sub        sub        shot       rebound    shot
#  [2953] rebound    shot       foul       shot       foul       sub
#  [2959] shot       rebound    foul       foul       free throw free throw
#  [2965] shot       rebound    shot       rebound    turnover   shot
#  [2971] rebound    foul       timeout    sub        free throw free throw
#  [2977] shot       shot       rebound    shot       rebound    shot
#  [2983] rebound    shot       shot       rebound    shot       rebound
#  [2989] foul       turnover   sub        turnover   shot       shot
#  [2995] rebound    shot       rebound    shot       shot       shot
#  [3001] rebound    shot       rebound    shot       rebound    shot
#  [3007] shot       rebound    shot       shot       shot       rebound
#  [3013] shot       foul       turnover   shot       rebound    shot
#  [3019] shot       shot       rebound    shot       shot       foul
#  [3025] free throw rebound    shot       foul       shot       shot
#  [3031] rebound    shot       rebound    foul       free throw sub
#  [3037] free throw foul       shot       rebound    foul       timeout
#  [3043] free throw free throw shot       shot       rebound    shot
#  [3049] shot       rebound    turnover   shot       rebound    shot
#  [3055] rebound    shot       shot       rebound    shot       rebound
#  [3061] shot       rebound    turnover   shot       shot       rebound
#  [3067] timeout    sub        sub        sub        sub        turnover
#  [3073] shot       foul       turnover   sub        turnover   shot
#  [3079] foul       turnover   shot       shot       rebound    foul
#  [3085] free throw free throw shot       rebound    foul       shot
#  [3091] rebound    shot       shot       rebound    shot       rebound
#  [3097] turnover   shot       foul       sub        sub        free throw
#  [3103] free throw shot       rebound    timeout    sub        sub
#  [3109] shot       rebound    shot       rebound    foul       shot
#  [3115] shot       foul       free throw jump ball  shot       rebound
#  [3121] foul       free throw free throw foul       free throw rebound
#  [3127] free throw shot       rebound    shot       rebound    shot
#  [3133] timeout    sub        sub        sub        shot       rebound
#  [3139] turnover   shot       rebound    foul       sub        free throw
#  [3145] free throw shot       rebound    foul       free throw free throw
#  [3151] shot       shot       rebound    shot       rebound    foul
#  [3157] free throw sub        free throw shot       foul       turnover
#  [3163] shot       rebound    shot       rebound    timeout    shot
#  [3169] rebound    shot       foul       free throw rebound    foul
#  [3175] free throw free throw shot       rebound    shot       shot
#  [3181] shot       foul       timeout    free throw free throw shot
#  [3187] rebound    foul       free throw free throw shot       shot
#  [3193] rebound    shot       turnover   shot       timeout    turnover
#  [3199] foul       free throw rebound    free throw foul       free throw
#  [3205] free throw turnover   turnover   sub        shot       rebound
#  [3211] foul       free throw free throw foul       free throw free throw
#  [3217] rebound    shot       rebound    shot       rebound    shot
#  [3223] rebound    foul       free throw free throw rebound    shot
#  [3229] foul       free throw free throw rebound    jump ball  shot
#  [3235] rebound    shot       shot       rebound    shot       foul
#  [3241] free throw shot       rebound    turnover   shot       shot
#  [3247] shot       shot       shot       rebound    shot       rebound
#  [3253] shot       shot       shot       foul       free throw shot
#  [3259] foul       sub        free throw shot       shot       rebound
#  [3265] shot       rebound    shot       rebound    turnover   foul
#  [3271] free throw rebound    free throw timeout    turnover   shot
#  [3277] rebound    shot       rebound    shot       rebound    shot
#  [3283] rebound    shot       shot       foul       free throw free throw
#  [3289] shot       rebound    shot       foul       sub        free throw
#  [3295] free throw rebound    shot       rebound    turnover   shot
#  [3301] rebound    shot       rebound    shot       rebound    foul
#  [3307] free throw turnover   shot       shot       rebound    shot
#  [3313] shot       shot       rebound    shot       rebound    shot
#  [3319] foul       sub        free throw turnover   shot       turnover
#  [3325] shot       rebound    shot       shot       timeout    sub
#  [3331] sub        sub        sub        sub        foul       free throw
#  [3337] rebound    free throw turnover   shot       shot       rebound
#  [3343] shot       rebound    shot       shot       rebound    shot
#  [3349] rebound    shot       rebound    shot       rebound    shot
#  [3355] rebound    foul       free throw sub        sub        sub
#  [3361] free throw shot       rebound    shot       shot       rebound
#  [3367] shot       violation  foul       foul       foul       shot
#  [3373] rebound    turnover   shot       foul       shot       rebound
#  [3379] shot       rebound    foul       sub        turnover   shot
#  [3385] rebound    shot       shot       rebound    shot       turnover
#  [3391] foul       free throw rebound    sub        free throw rebound
#  [3397] shot       turnover   shot       rebound    shot       rebound
#  [3403] foul       timeout    sub        sub        free throw rebound
#  [3409] free throw shot       shot       rebound    shot       shot
#  [3415] shot       rebound    foul       sub        sub        shot
#  [3421] turnover   foul       free throw sub        free throw jump ball
#  [3427] turnover   shot       foul       sub        free throw rebound
#  [3433] timeout    free throw rebound    shot       turnover   shot
#  [3439] foul       free throw sub        free throw shot       shot
#  [3445] rebound    shot       timeout    shot       rebound    turnover
#  [3451] shot       rebound    shot       rebound    shot       shot
#  [3457] shot       rebound    shot       rebound    shot       rebound
#  [3463] shot       shot       rebound    shot       shot       rebound
#  [3469] shot       shot       foul       free throw foul       free throw
#  [3475] free throw shot       shot       rebound    shot       violation
#  [3481] shot       rebound    foul       sub        free throw sub
#  [3487] free throw rebound    free throw shot       rebound    shot
#  [3493] rebound    shot       shot       rebound    shot       shot
#  [3499] rebound    shot       shot       rebound    shot       rebound
#  [3505] foul       free throw turnover   shot       rebound    shot
#  [3511] rebound    shot       shot       foul       shot       rebound
#  [3517] shot       timeout    shot       turnover   shot       rebound
#  [3523] foul       shot       rebound    shot       rebound    shot
#  [3529] rebound    shot       foul       free throw shot       rebound
#  [3535] foul       turnover   shot       rebound    turnover   shot
#  [3541] rebound    shot       rebound    shot       timeout    sub
#  [3547] shot       shot       rebound    shot       rebound    rebound
#  [3553] shot       rebound    shot       rebound    foul       shot
#  [3559] foul       sub        free throw rebound    turnover   foul
#  [3565] turnover   shot       rebound    shot       rebound    sub
#  [3571] foul       free throw free throw shot       rebound    shot
#  [3577] rebound    foul       sub        free throw sub        free throw
#  [3583] shot       rebound    shot       rebound    shot       timeout
#  [3589] sub        sub        sub        shot       shot       shot
#  [3595] rebound    shot       rebound    turnover   turnover   sub
#  [3601] turnover   shot       shot       foul       sub        free throw
#  [3607] free throw turnover   shot       shot       foul       free throw
#  [3613] turnover   shot       shot       rebound    foul       shot
#  [3619] rebound    shot       rebound    shot       rebound    shot
#  [3625] shot       shot       foul       free throw free throw shot
#  [3631] rebound    shot       shot       foul       free throw shot
#  [3637] shot       timeout    shot       rebound    foul       sub
#  [3643] foul       shot       rebound    turnover   shot       rebound
#  [3649] shot       rebound    turnover   shot       rebound    foul
#  [3655] free throw free throw turnover   turnover   foul       sub
#  [3661] sub        shot       rebound    shot       rebound    shot
#  [3667] rebound    shot       rebound    shot       shot       shot
#  [3673] shot       shot       rebound    shot       rebound    shot
#  [3679] shot       rebound    turnover   shot       shot       shot
#  [3685] foul       timeout    sub        sub        sub        free throw
#  [3691] free throw shot       turnover   shot       rebound    shot
#  [3697] shot       rebound    shot       violation  shot       rebound
#  [3703] shot       timeout    sub        sub        sub        sub
#  [3709] sub        foul       free throw free throw shot       rebound
#  [3715] turnover   shot       rebound    turnover   shot       shot
#  [3721] rebound    turnover   shot       shot       rebound    foul
#  [3727] free throw free throw rebound    turnover   shot       shot
#  [3733] rebound    foul       free throw free throw jump ball  shot
#  [3739] rebound    shot       rebound    turnover   foul       free throw
#  [3745] free throw turnover   turnover   shot       rebound    shot
#  [3751] rebound    shot       shot       rebound    shot       shot
#  [3757] rebound    turnover   shot       shot       foul       shot
#  [3763] rebound    shot       turnover   shot       rebound    shot
#  [3769] rebound    shot       rebound    shot       rebound    shot
#  [3775] rebound    shot       shot       rebound    shot       rebound
#  [3781] shot       rebound    shot       shot       foul       free throw
#  [3787] free throw shot       rebound    shot       rebound    shot
#  [3793] rebound    shot       rebound    shot       foul       timeout
#  [3799] sub        sub        free throw rebound    shot       rebound
#  [3805] shot       shot       shot       rebound    shot       shot
#  [3811] shot       rebound    shot       shot       shot       foul
#  [3817] timeout    sub        sub        sub        free throw shot
#  [3823] rebound    shot       shot       rebound    shot       shot
#  [3829] rebound    shot       shot       rebound    foul       sub
#  [3835] sub        shot       foul       shot       rebound    shot
#  [3841] shot       rebound    shot       turnover   shot       shot
#  [3847] turnover   shot       foul       sub        free throw rebound
#  [3853] foul       shot       rebound    shot       shot       rebound
#  [3859] turnover   shot       shot       foul       timeout    free throw
#  [3865] shot       rebound    shot       rebound    shot       rebound
#  [3871] shot       rebound    shot       shot       rebound    foul
#  [3877] free throw rebound    sub        free throw shot       rebound
# ...
# [33337] turnover   timeout    sub        sub        shot       rebound
# [33343] shot       shot       rebound    shot       rebound    turnover
# [33349] foul       sub        sub        sub        shot       rebound
# [33355] foul       free throw rebound    sub        free throw shot
# [33361] rebound    shot       foul       shot       rebound    shot
# [33367] shot       rebound    foul       timeout    sub        free throw
# [33373] free throw shot       rebound    violation  sub        foul
# [33379] free throw free throw shot       foul       turnover   shot
# [33385] rebound    shot       shot       rebound    shot       shot
# [33391] rebound    shot       shot       rebound    shot       rebound
# [33397] shot       rebound    shot       shot       foul       sub
# [33403] shot       rebound    shot       shot       rebound    shot
# [33409] shot       shot       shot       foul       free throw shot
# [33415] rebound    shot       rebound    shot       turnover   timeout
# [33421] shot       rebound    shot       shot       rebound    turnover
# [33427] shot       rebound    foul       free throw free throw shot
# [33433] shot       shot       rebound    foul       turnover   sub
# [33439] timeout    sub        sub        sub        sub        shot
# [33445] rebound    shot       rebound    sub        sub        shot
# [33451] rebound    foul       free throw free throw rebound    foul
# [33457] turnover   foul       free throw free throw shot       rebound
# [33463] shot       rebound    shot       shot       shot       shot
# [33469] rebound    shot       shot       rebound    timeout    shot
# [33475] rebound    shot       foul       timeout    rebound    shot
# [33481] foul       sub        free throw free throw shot       shot
# [33487] rebound    shot       shot       rebound    shot       rebound
# [33493] foul       sub        sub        shot       shot       rebound
# [33499] foul       free throw sub        sub        sub        sub
# [33505] free throw shot       shot       rebound    shot       rebound
# [33511] foul       shot       shot       rebound    rebound    shot
# [33517] rebound    shot       shot       shot       rebound    shot
# [33523] shot       shot       rebound    shot       foul       free throw
# [33529] rebound    turnover   shot       shot       foul       free throw
# [33535] rebound    foul       shot       rebound    shot       rebound
# [33541] foul       free throw free throw shot       rebound    foul
# [33547] free throw free throw shot       rebound    shot       rebound
# [33553] shot       shot       rebound    foul       timeout    sub
# [33559] sub        sub        free throw free throw shot       shot
# [33565] foul       shot       shot       rebound    shot       foul
# [33571] sub        free throw shot       rebound    shot       timeout
# [33577] sub        shot       rebound    foul       shot       shot
# [33583] rebound    shot       shot       rebound    shot       shot
# [33589] rebound    turnover   sub        shot       foul       free throw
# [33595] rebound    free throw shot       rebound    foul       free throw
# [33601] rebound    free throw shot       shot       rebound    shot
# [33607] shot       rebound    shot       rebound    shot       turnover
# [33613] shot       shot       rebound    shot       rebound    shot
# [33619] rebound    shot       rebound    shot       rebound    shot
# [33625] shot       foul       free throw rebound    free throw rebound
# [33631] shot       shot       rebound    foul       shot       foul
# [33637] free throw rebound    free throw rebound    shot       foul
# [33643] timeout    sub        sub        foul       sub        foul
# [33649] free throw free throw shot       rebound    foul       free throw
# [33655] rebound    free throw rebound    turnover   shot       shot
# [33661] shot       rebound    foul       turnover   sub        foul
# [33667] free throw free throw shot       foul       turnover   timeout
# [33673] sub        sub        shot       shot       shot       rebound
# [33679] foul       free throw sub        free throw shot       shot
# [33685] rebound    shot       rebound    shot       shot       foul
# [33691] free throw shot       foul       free throw sub        free throw
# [33697] shot       rebound    shot       rebound    shot       shot
# [33703] rebound    timeout    sub        shot       rebound    timeout
# [33709] sub        shot       rebound    timeout    sub        shot
# [33715] rebound    foul       free throw rebound    free throw turnover
# [33721] timeout    sub        sub        foul       free throw rebound
# [33727] sub        sub        free throw timeout    sub        sub
# [33733] shot       rebound    foul       free throw free throw shot
# [33739] rebound    foul       sub        free throw rebound    free throw
# [33745] shot       rebound    jump ball  shot       shot       rebound
# [33751] shot       shot       rebound    shot       rebound    shot
# [33757] rebound    shot       rebound    turnover   shot       rebound
# [33763] foul       shot       shot       shot       rebound    shot
# [33769] rebound    shot       shot       rebound    shot       turnover
# [33775] shot       shot       rebound    foul       shot       rebound
# [33781] shot       shot       foul       sub        free throw rebound
# [33787] free throw rebound    shot       rebound    shot       rebound
# [33793] shot       rebound    shot       shot       rebound    shot
# [33799] rebound    foul       timeout    shot       shot       shot
# [33805] rebound    shot       shot       rebound    shot       rebound
# [33811] shot       rebound    shot       rebound    turnover   timeout
# [33817] sub        sub        sub        shot       rebound    shot
# [33823] turnover   shot       rebound    shot       rebound    shot
# [33829] rebound    shot       rebound    shot       shot       foul
# [33835] sub        shot       rebound    turnover   shot       shot
# [33841] turnover   shot       foul       sub        free throw turnover
# [33847] foul       shot       rebound    foul       sub        free throw
# [33853] free throw shot       rebound    shot       rebound    shot
# [33859] rebound    foul       free throw sub        free throw turnover
# [33865] turnover   foul       timeout    sub        free throw free throw
# [33871] rebound    shot       rebound    shot       rebound    shot
# [33877] rebound    shot       rebound    foul       free throw sub
# [33883] sub        free throw shot       rebound    shot       foul
# [33889] shot       turnover   shot       rebound    shot       rebound
# [33895] shot       rebound    shot       timeout    sub        sub
# [33901] sub        shot       shot       shot       shot       shot
# [33907] rebound    foul       free throw rebound    free throw rebound
# [33913] shot       foul       sub        sub        sub        sub
# [33919] shot       rebound    shot       shot       rebound    shot
# [33925] foul       timeout    free throw rebound    shot       foul
# [33931] turnover   sub        shot       rebound    foul       free throw
# [33937] free throw shot       rebound    foul       free throw sub
# [33943] free throw shot       rebound    shot       rebound    shot
# [33949] shot       rebound    shot       rebound    shot       shot
# [33955] shot       rebound    foul       turnover   sub        shot
# [33961] rebound    foul       shot       rebound    shot       foul
# [33967] shot       rebound    foul       shot       rebound    shot
# [33973] shot       turnover   shot       rebound    foul       free throw
# [33979] free throw foul       shot       rebound    shot       rebound
# [33985] turnover   shot       shot       rebound    foul       timeout
# [33991] sub        turnover   turnover   shot       rebound    shot
# [33997] rebound    shot       rebound    sub        turnover   shot
# [34003] foul       shot       shot       rebound    shot       shot
# [34009] shot       rebound    turnover   foul       free throw free throw
# [34015] shot       rebound    shot       shot       shot       rebound
# [34021] shot       rebound    shot       timeout    sub        turnover
# [34027] shot       turnover   shot       shot       shot       shot
# [34033] shot       shot       foul       timeout    sub        sub
# [34039] free throw shot       rebound    shot       rebound    shot
# [34045] rebound    foul       free throw shot       rebound    shot
# [34051] shot       rebound    turnover   shot       rebound    shot
# [34057] rebound    shot       rebound    shot       rebound    shot
# [34063] turnover   turnover   timeout    sub        foul       foul
# [34069] turnover   shot       rebound    shot       shot       rebound
# [34075] shot       rebound    foul       free throw free throw turnover
# [34081] shot       shot       shot       rebound    sub        shot
# [34087] shot       rebound    shot       rebound    foul       timeout
# [34093] sub        sub        shot       rebound    shot       foul
# [34099] shot       turnover   shot       shot       rebound    shot
# [34105] rebound    sub        sub        sub        foul       free throw
# [34111] free throw shot       shot       shot       rebound    foul
# [34117] free throw sub        sub        sub        free throw turnover
# [34123] shot       rebound    shot       foul       timeout    sub
# [34129] free throw free throw shot       foul       free throw rebound
# [34135] shot       rebound    turnover   shot       rebound    shot
# [34141] rebound    shot       rebound    shot       rebound    turnover
# [34147] sub        foul       foul       free throw free throw shot
# [34153] rebound    jump ball  shot       rebound    turnover   shot
# [34159] shot       rebound    shot       rebound    shot       shot
# [34165] shot       shot       shot       rebound    foul       free throw
# [34171] free throw turnover   foul       free throw free throw foul
# [34177] shot       shot       rebound    shot       foul       free throw
# [34183] rebound    free throw rebound    shot       shot       rebound
# [34189] turnover   turnover   turnover   shot       shot       rebound
# [34195] shot       rebound    turnover   shot       shot       timeout
# [34201] shot       rebound    shot       shot       foul       free throw
# [34207] rebound    free throw foul       shot       rebound    shot
# [34213] foul       sub        free throw free throw rebound    shot
# [34219] rebound    shot       turnover   shot       rebound    shot
# [34225] shot       rebound    shot       foul       timeout    sub
# [34231] sub        sub        sub        sub        free throw shot
# [34237] rebound    shot       rebound    shot       rebound    shot
# [34243] shot       rebound    turnover   turnover   shot       rebound
# [34249] foul       sub        sub        free throw sub        free throw
# [34255] foul       free throw rebound    free throw shot       rebound
# [34261] shot       shot       foul       free throw sub        sub
# [34267] free throw shot       rebound    foul       free throw free throw
# [34273] rebound    shot       rebound    shot       rebound    foul
# [34279] free throw free throw shot       turnover   turnover   shot
# [34285] shot       foul       free throw foul       free throw free throw
# [34291] foul       shot       foul       free throw sub        free throw
# [34297] shot       rebound    shot       rebound    turnover   shot
# [34303] foul       timeout    sub        sub        shot       rebound
# [34309] shot       shot       foul       sub        free throw rebound
# [34315] foul       turnover   shot       shot       foul       free throw
# [34321] sub        sub        free throw shot       shot       rebound
# [34327] shot       turnover   timeout    sub        sub        sub
# [34333] shot       rebound    turnover   shot       shot       rebound
# [34339] shot       violation  shot       foul       foul       free throw
# [34345] free throw shot       shot       rebound    rebound    shot
# [34351] rebound    foul       free throw free throw shot       shot
# [34357] rebound    shot       timeout    sub        sub        shot
# [34363] shot       foul       free throw foul       free throw rebound
# [34369] sub        free throw violation  turnover   shot       foul
# [34375] sub        free throw rebound    shot       rebound    foul
# [34381] free throw free throw turnover   foul       turnover   shot
# [34387] shot       rebound    shot       rebound    shot       rebound
# [34393] shot       rebound    shot       rebound    shot       rebound
# [34399] shot       rebound    foul       shot       shot       rebound
# [34405] shot       shot       shot       rebound    shot       foul
# [34411] shot       foul       free throw free throw shot       rebound
# [34417] shot       rebound    shot       rebound    shot       shot
# [34423] rebound    foul       shot       rebound    shot       rebound
# [34429] shot       rebound    foul       turnover   shot       rebound
# [34435] turnover   shot       rebound    foul       shot       shot
# [34441] rebound    shot       turnover   foul       free throw free throw
# [34447] rebound    shot       shot       rebound    shot       shot
# [34453] foul       turnover   foul       timeout    shot       rebound
# [34459] shot       rebound    shot       rebound    foul       sub
# [34465] sub        sub        sub        shot       foul       free throw
# [34471] free throw shot       shot       foul       free throw free throw
# [34477] rebound    shot       timeout    sub        shot       foul
# [34483] free throw foul       free throw free throw shot       foul
# [34489] free throw turnover   shot       rebound    shot       shot
# [34495] foul       free throw sub        sub        free throw shot
# [34501] rebound    shot       rebound    shot       rebound    shot
# [34507] shot       shot       foul       free throw sub        sub
# [34513] free throw foul       free throw rebound    free throw shot
# [34519] turnover   shot       foul       turnover   shot       shot
# [34525] rebound    sub        jump ball  turnover   shot       shot
# [34531] shot       foul       shot       rebound    foul       free throw
# [34537] free throw rebound    foul       timeout    sub        shot
# [34543] rebound    shot       rebound    shot       shot       shot
# [34549] foul       free throw sub        sub        free throw shot
# [34555] rebound    shot       shot       rebound    turnover   shot
# [34561] shot       rebound    foul       turnover   shot       shot
# [34567] rebound    foul       timeout    sub        shot       foul
# [34573] free throw free throw shot       shot       shot       turnover
# [34579] shot       foul       free throw rebound    sub        sub
# [34585] free throw shot       shot       shot       rebound    shot
# [34591] shot       rebound    shot       turnover   timeout    sub
# [34597] sub        sub        shot       rebound    shot       shot
# [34603] rebound    shot       rebound    foul       free throw rebound
# [34609] free throw shot       shot       rebound    shot       rebound
# [34615] turnover   foul       free throw free throw foul       free throw
# [34621] free throw turnover   shot       rebound
# 10 Levels: ejection foul free throw jump ball rebound shot sub ... violation

# %%
myname <- "gittu"
str(myname)
# Out:
#  chr "gittu"

# %% [markdown]
# Then we can use `as.factor` to convert it to a factor column:
# > Note: By default, factor levels are ordered alphabetically.

# %%
lakers_factor <- lakers |>
  mutate(etype = as.factor(etype))

str(lakers_factor$etype)
levels(lakers_factor$etype)
# Out:
#  Factor w/ 10 levels "ejection","foul",..: 4 6 5 6 5 6 2 3 2 6 ...
#  [1] "ejection"   "foul"       "free throw" "jump ball"  "rebound"
#  [6] "shot"       "sub"        "timeout"    "turnover"   "violation"

# %% [markdown]
# You can use `fct_reorder` to order one variable by another. The factor is the grouping variable and the default summarizing function is median but you can specify something else.

# %%
lakers_factor <- lakers_factor |> mutate(etype = fct_reorder(etype,period,min))

# %%
lakers_factor$etype |> levels()
# Out:
#  [1] "foul"       "free throw" "jump ball"  "rebound"    "shot"
#  [6] "sub"        "timeout"    "turnover"   "violation"  "ejection"

# %%
nchar(as.factor(c("gittu","gittu")))
# Out:
# Error in nchar(as.factor(c("gittu", "gittu"))): 'nchar()' requires a character vector
# Traceback:
#
# 1. nchar(as.factor(c("gittu", "gittu")))

# %%
str_length(as.factor(c("gittu","gittu")))
# Out:
# [1] 5 5

# %%
lakers_factor
# Out:
#       date     opponent game_type time  period etype     team
# 1     20081028 POR      home      12:00 1      jump ball OFF
# 2     20081028 POR      home      11:39 1      shot      LAL
# 3     20081028 POR      home      11:37 1      rebound   LAL
# ...   ...      ...      ...       ...   ...    ...       ...
# 34622 20090414 UTA      home      00:27 4      turnover  LAL
# 34623 20090414 UTA      home      00:21 4      shot      UTA
# 34624 20090414 UTA      home      00:20 4      rebound   LAL
#       player              result points type x   y
# 1                                0           NA  NA
# 2     Pau Gasol           missed 0      hook 23  13
# 3     Vladimir Radmanovic        0      off  NA  NA
# ...   ...                 ...    ...    ...  ... ...
# 34622 Andrew Bynum               0           NA  NA
# 34623 Kyle Korver         missed 0      3pt  41  25
# 34624 Luke Walton                0      def  NA  NA

# %% [markdown]
# In the lab, you will explore how factor levels impact data visualization. And next block, in DSCI 552 you will start to use them for statistical analysis.
